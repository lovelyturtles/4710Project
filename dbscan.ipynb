# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.cluster import DBSCAN
from statsmodels.graphics.mosaicplot import mosaic

# %%
df = pd.read_csv("cleanedSample.csv",low_memory=False)

# %%
df
# Out:
#        Longitude   Latitude              Street        Day Violation Code
# 0      49.892600 -97.153600           Spence ST    Tuesday            P30
# 1      49.889300 -97.147600         St Mary AVE    Tuesday            P64
# 2      49.839515 -97.151106  LOT72-1360 PEMBINA    Tuesday             16
# 3      49.893690 -97.153870           Spence ST  Wednesday            P05
# 4      49.898700 -97.133400           James AVE     Friday            P02
# ...          ...        ...                 ...        ...            ...
# 99995  49.903700 -97.166100      Notre Dame AVE     Monday            P03
# 99996  49.891700 -97.142800           Donald ST    Tuesday            P03
# 99997  49.885200 -97.141900          Carlton ST    Tuesday            P01
# 99998  49.892800 -97.154900          Ellice AVE   Thursday            P03
# 99999  49.893143 -97.154835            Young ST    Tuesday            P05
#
# [100000 rows x 5 columns]

# %%
# Select the columns to encode
columns_to_encode = ['Day', 'Violation Code', 'Street']

# Create the OneHotEncoder object
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore',dtype=np.bool_)

# Fit the encoder to the data
encoder.fit(df[columns_to_encode])

# Transform the data
encoded_data = encoder.transform(df[columns_to_encode])

# Create column names for the encoded data
encoded_columns = encoder.get_feature_names_out(columns_to_encode)

encoded_columns_df = pd.DataFrame(encoded_data, columns=encoded_columns)

encoded_columns_df = encoded_columns_df.astype(np.bool_)

# %%
encoded_columns_df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False       False         False       False         False
# 1           False       False         False       False         False
# 2           False       False         False       False         False
# 3           False       False         False       False         False
# 4            True       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995       False        True         False       False         False
# 99996       False       False         False       False         False
# 99997       False       False         False       False         False
# 99998       False       False         False       False          True
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0             True          False             False              False
# 1             True          False             False              False
# 2             True          False             False              False
# 3            False           True             False              False
# 4            False          False             False              False
# ...            ...            ...               ...                ...
# 99995        False          False             False              False
# 99996         True          False             False              False
# 99997         True          False             False              False
# 99998        False          False             False              False
# 99999         True          False             False              False
#
#        Violation Code_11  ...  Street_Yanofsky WAY  Street_Yardley ST  \
# 0                  False  ...                False              False
# 1                  False  ...                False              False
# 2                  False  ...                False              False
# 3                  False  ...                False              False
# 4                  False  ...                False              False
# ...                  ...  ...                  ...                ...
# 99995              False  ...                False              False
# 99996              False  ...                False              False
# 99997              False  ...                False              False
# 99998              False  ...                False              False
# 99999              False  ...                False              False
#
#        Street_Yarmouth COVE  Street_Yarwood AVE  Street_Yeomans ST  \
# 0                     False               False              False
# 1                     False               False              False
# 2                     False               False              False
# 3                     False               False              False
# 4                     False               False              False
# ...                     ...                 ...                ...
# 99995                 False               False              False
# 99996                 False               False              False
# 99997                 False               False              False
# 99998                 False               False              False
# 99999                 False               False              False
#
#        Street_York AVE  Street_York Valley Way  Street_Yorkwood DR  \
# 0                False                   False               False
# 1                False                   False               False
# 2                False                   False               False
# 3                False                   False               False
# 4                False                   False               False
# ...                ...                     ...                 ...
# 99995            False                   False               False
# 99996            False                   False               False
# 99997            False                   False               False
# 99998            False                   False               False
# 99999            False                   False               False
#
#        Street_Young ST  Street_Zawaly BAY
# 0                False              False
# 1                False              False
# 2                False              False
# 3                False              False
# 4                False              False
# ...                ...                ...
# 99995            False              False
# 99996            False              False
# 99997            False              False
# 99998            False              False
# 99999             True              False
#
# [100000 rows x 2705 columns]

# %%
df = df[['Longitude','Latitude']]
df = df.astype(np.float16)
encoded_columns_df["Latitude"] = df["Latitude"]
encoded_columns_df["Longitude"] = df["Longitude"]

# %%
df = encoded_columns_df
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False       False         False       False         False
# 1           False       False         False       False         False
# 2           False       False         False       False         False
# 3           False       False         False       False         False
# 4            True       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995       False        True         False       False         False
# 99996       False       False         False       False         False
# 99997       False       False         False       False         False
# 99998       False       False         False       False          True
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0             True          False             False              False
# 1             True          False             False              False
# 2             True          False             False              False
# 3            False           True             False              False
# 4            False          False             False              False
# ...            ...            ...               ...                ...
# 99995        False          False             False              False
# 99996         True          False             False              False
# 99997         True          False             False              False
# 99998        False          False             False              False
# 99999         True          False             False              False
#
#        Violation Code_11  ...  Street_Yanofsky WAY  Street_Yardley ST  \
# 0                  False  ...                False              False
# 1                  False  ...                False              False
# 2                  False  ...                False              False
# 3                  False  ...                False              False
# 4                  False  ...                False              False
# ...                  ...  ...                  ...                ...
# 99995              False  ...                False              False
# 99996              False  ...                False              False
# 99997              False  ...                False              False
# 99998              False  ...                False              False
# 99999              False  ...                False              False
#
#        Street_Yarmouth COVE  Street_Yarwood AVE  Street_Yeomans ST  \
# 0                     False               False              False
# 1                     False               False              False
# 2                     False               False              False
# 3                     False               False              False
# 4                     False               False              False
# ...                     ...                 ...                ...
# 99995                 False               False              False
# 99996                 False               False              False
# 99997                 False               False              False
# 99998                 False               False              False
# 99999                 False               False              False
#
#        Street_York AVE  Street_York Valley Way  Street_Yorkwood DR  \
# 0                False                   False               False
# 1                False                   False               False
# 2                False                   False               False
# 3                False                   False               False
# 4                False                   False               False
# ...                ...                     ...                 ...
# 99995            False                   False               False
# 99996            False                   False               False
# 99997            False                   False               False
# 99998            False                   False               False
# 99999            False                   False               False
#
#        Street_Young ST  Street_Zawaly BAY
# 0                False              False
# 1                False              False
# 2                False              False
# 3                False              False
# 4                False              False
# ...                ...                ...
# 99995            False              False
# 99996            False              False
# 99997            False              False
# 99998            False              False
# 99999             True              False
#
# [100000 rows x 2705 columns]

# %%
numericalCols = ["Longitude","Latitude"]
numericalData = df[numericalCols]

# standardize the numerical data to have a mean of 0 and a variance of 1
scaler = StandardScaler()
numericalDataScaled = scaler.fit_transform(numericalData)
df[numericalCols] = numericalDataScaled
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False       False         False       False         False
# 1           False       False         False       False         False
# 2           False       False         False       False         False
# 3           False       False         False       False         False
# 4            True       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995       False        True         False       False         False
# 99996       False       False         False       False         False
# 99997       False       False         False       False         False
# 99998       False       False         False       False          True
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0             True          False             False              False
# 1             True          False             False              False
# 2             True          False             False              False
# 3            False           True             False              False
# 4            False          False             False              False
# ...            ...            ...               ...                ...
# 99995        False          False             False              False
# 99996         True          False             False              False
# 99997         True          False             False              False
# 99998        False          False             False              False
# 99999         True          False             False              False
#
#        Violation Code_11  ...  Street_Yarmouth COVE  Street_Yarwood AVE  \
# 0                  False  ...                 False               False
# 1                  False  ...                 False               False
# 2                  False  ...                 False               False
# 3                  False  ...                 False               False
# 4                  False  ...                 False               False
# ...                  ...  ...                   ...                 ...
# 99995              False  ...                 False               False
# 99996              False  ...                 False               False
# 99997              False  ...                 False               False
# 99998              False  ...                 False               False
# 99999              False  ...                 False               False
#
#        Street_Yeomans ST  Street_York AVE  Street_York Valley Way  \
# 0                  False            False                   False
# 1                  False            False                   False
# 2                  False            False                   False
# 3                  False            False                   False
# 4                  False            False                   False
# ...                  ...              ...                     ...
# 99995              False            False                   False
# 99996              False            False                   False
# 99997              False            False                   False
# 99998              False            False                   False
# 99999              False            False                   False
#
#        Street_Yorkwood DR  Street_Young ST  Street_Zawaly BAY  Latitude  \
# 0                   False            False              False  0.367188
# 1                   False            False              False  0.367188
# 2                   False            False              False  0.367188
# 3                   False            False              False  0.367188
# 4                   False            False              False  0.367188
# ...                   ...              ...                ...       ...
# 99995               False            False              False -1.273438
# 99996               False            False              False  0.367188
# 99997               False            False              False  0.367188
# 99998               False            False              False  0.367188
# 99999               False             True              False  0.367188
#
#        Longitude
# 0       0.584961
# 1      -0.569824
# 2      -1.724609
# 3       0.584961
# 4       0.584961
# ...          ...
# 99995   0.584961
# 99996   0.584961
# 99997  -0.569824
# 99998   0.584961
# 99999   0.584961
#
# [100000 rows x 2707 columns]

# %%
# create a DBSCAN object and fit the data
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(df)

# add the cluster labels to the original dataframe
df['Clusters'] = dbscan.labels_

# %%
plt.scatter(df['Longitude'], df['Latitude'], c=df["Clusters"])
plt.title('Clustered Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False       False         False       False         False
# 1           False       False         False       False         False
# 2           False       False         False       False         False
# 3           False       False         False       False         False
# 4            True       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995       False        True         False       False         False
# 99996       False       False         False       False         False
# 99997       False       False         False       False         False
# 99998       False       False         False       False          True
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0             True          False             False              False
# 1             True          False             False              False
# 2             True          False             False              False
# 3            False           True             False              False
# 4            False          False             False              False
# ...            ...            ...               ...                ...
# 99995        False          False             False              False
# 99996         True          False             False              False
# 99997         True          False             False              False
# 99998        False          False             False              False
# 99999         True          False             False              False
#
#        Violation Code_11  ...  Street_Yardley ST  Street_Yarmouth COVE  \
# 0                  False  ...              False                 False
# 1                  False  ...              False                 False
# 2                  False  ...              False                 False
# 3                  False  ...              False                 False
# 4                  False  ...              False                 False
# ...                  ...  ...                ...                   ...
# 99995              False  ...              False                 False
# 99996              False  ...              False                 False
# 99997              False  ...              False                 False
# 99998              False  ...              False                 False
# 99999              False  ...              False                 False
#
#        Street_Yarwood AVE  Street_Yeomans ST  Street_York AVE  \
# 0                   False              False            False
# 1                   False              False            False
# 2                   False              False            False
# 3                   False              False            False
# 4                   False              False            False
# ...                   ...                ...              ...
# 99995               False              False            False
# 99996               False              False            False
# 99997               False              False            False
# 99998               False              False            False
# 99999               False              False            False
#
#        Street_York Valley Way  Street_Yorkwood DR  Street_Young ST  \
# 0                       False               False            False
# 1                       False               False            False
# 2                       False               False            False
# 3                       False               False            False
# 4                       False               False            False
# ...                       ...                 ...              ...
# 99995                   False               False            False
# 99996                   False               False            False
# 99997                   False               False            False
# 99998                   False               False            False
# 99999                   False               False             True
#
#        Street_Zawaly BAY  Clusters
# 0                  False         0
# 1                  False         1
# 2                  False        -1
# 3                  False         2
# 4                  False         3
# ...                  ...       ...
# 99995              False      2941
# 99996              False       929
# 99997              False       546
# 99998              False      2094
# 99999              False       595
#
# [100000 rows x 2706 columns]

# %%
decoded_data = encoder.inverse_transform(encoded_data)
decoded_data
# Out:
# array([['Tuesday', 'P30', 'Spence ST'],
#        ['Tuesday', 'P64', 'St Mary AVE'],
#        ['Tuesday', '16', 'LOT72-1360 PEMBINA'],
#        ...,
#        ['Tuesday', 'P01', 'Carlton ST'],
#        ['Thursday', 'P03', 'Ellice AVE'],
#        ['Tuesday', 'P05', 'Young ST']], dtype=object)

# %%
decodedDf= pd.DataFrame(decoded_data,columns=["Day","Violation Code","Street"])
decodedDf["Cluster"]=df["Clusters"]
decodedDf
# Out:
#              Day Violation Code              Street  Cluster
# 0        Tuesday            P30           Spence ST        0
# 1        Tuesday            P64         St Mary AVE        1
# 2        Tuesday             16  LOT72-1360 PEMBINA       -1
# 3      Wednesday            P05           Spence ST        2
# 4         Friday            P02           James AVE        3
# ...          ...            ...                 ...      ...
# 99995     Monday            P03      Notre Dame AVE     2941
# 99996    Tuesday            P03           Donald ST      929
# 99997    Tuesday            P01          Carlton ST      546
# 99998   Thursday            P03          Ellice AVE     2094
# 99999    Tuesday            P05            Young ST      595
#
# [100000 rows x 4 columns]

# %%
mosaic(decodedDf, ["Day","Violation Code","Street", 'Cluster'], title='Clustered Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# d:\OneDrive - University of Manitoba\Documents\School\COMP\4710\Project\4710Project\dbscan.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20University%20of%20Manitoba/Documents/School/COMP/4710/Project/4710Project/dbscan.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> mosaic(decodedDf, ["Day","Violation Code","Street", 'Cluster'], title='Clustered Data')
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20University%20of%20Manitoba/Documents/School/COMP/4710/Project/4710Project/dbscan.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\graphics\mosaicplot.py:629, in mosaic(data, index, ax, horizontal, gap, properties, labelizer, title, statistic, axes_label, label_rotation)
#     628 # normalize the data to a dict with tuple of strings as keys
# --> 629 data = _normalize_data(data, index)
#     630 # split the graph into different areas
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\graphics\mosaicplot.py:308, in _normalize_data(data, index)
#     307 indexes = product(*categories_levels)
# --> 308 contingency = dict([(k, data.get(k, 0)) for k in indexes])
#     309 data = contingency
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\graphics\mosaicplot.py:308, in <listcomp>(.0)
#     307 indexes = product(*categories_levels)
# --> 308 contingency = dict([(k, data.get(k, 0)) for k in indexes])
#     309 data = contingency
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3401, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3398             exec(code_obj, self.user_global_ns, self.user_ns)
#    3399     finally:
#    3400         # Reset our crash handler in place
# -> 3401         sys.excepthook = old_excepthook
#    3402 except SystemExit as e:
#    3403     if result is not None:
#
# KeyboardInterrupt:

# %%
cluster_labels = decodedDf['cluster_label']
data = data.drop('cluster_label', axis=1)
sns.heatmap(data, cmap='Blues', cbar=False, xticklabels=True, yticklabels=True)
plt.title('Clustered Data')
plt.xlabel('Features')
plt.ylabel('Samples')
plt.show()
