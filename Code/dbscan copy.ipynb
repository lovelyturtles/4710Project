# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("../Data/cleanedSample.csv",low_memory=False)

# %%
df
# Out:
#        Longitude   Latitude       Street        Day Violation Code
# 0      49.889043 -97.213038  Marjorie ST     Monday             37
# 1      49.889800 -97.145800  Edmonton ST     Friday              1
# 2      49.895800 -97.146300  Hargrave ST     Monday              2
# 3      49.889883 -97.147008  St Mary AVE   Thursday              1
# 4      49.889843 -97.136936      Fort ST  Wednesday              1
# ...          ...        ...          ...        ...            ...
# 99995  49.892040 -97.139610     Garry ST     Friday              1
# 99996  49.899393 -97.140131      King ST     Friday              1
# 99997  49.904600 -97.157500  William AVE     Friday              3
# 99998  49.886800 -97.145800   Kennedy ST    Tuesday              1
# 99999  49.892128 -97.152480  Balmoral ST  Wednesday              1
#
# [100000 rows x 5 columns]

# %%
# Select the columns to encode
columns_to_encode = ['Day', 'Violation Code', 'Street']

# Create the OneHotEncoder object
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore',dtype=np.bool_)

# Fit the encoder to the data
encoder.fit(df[columns_to_encode])

# Transform the data
encoded_data = encoder.transform(df[columns_to_encode])

# Create column names for the encoded data
encoded_columns = encoder.get_feature_names_out(columns_to_encode)

encoded_columns_df = pd.DataFrame(encoded_data, columns=encoded_columns)

encoded_columns_df = encoded_columns_df.astype(np.bool_)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
encoded_columns_df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0            False          False             False              False
# 1            False          False              True              False
# 2            False          False             False              False
# 3            False          False              True              False
# 4            False           True              True              False
# ...            ...            ...               ...                ...
# 99995        False          False              True              False
# 99996        False          False              True              False
# 99997        False          False             False              False
# 99998         True          False              True              False
# 99999        False           True              True              False
#
#        Violation Code_11  ...  Street_Yale AVE W  Street_Yanofsky WAY  \
# 0                  False  ...              False                False
# 1                  False  ...              False                False
# 2                  False  ...              False                False
# 3                  False  ...              False                False
# 4                  False  ...              False                False
# ...                  ...  ...                ...                  ...
# 99995              False  ...              False                False
# 99996              False  ...              False                False
# 99997              False  ...              False                False
# 99998              False  ...              False                False
# 99999              False  ...              False                False
#
#        Street_Yardley ST  Street_Yarwood AVE  Street_Yeomans ST  \
# 0                  False               False              False
# 1                  False               False              False
# 2                  False               False              False
# 3                  False               False              False
# 4                  False               False              False
# ...                  ...                 ...                ...
# 99995              False               False              False
# 99996              False               False              False
# 99997              False               False              False
# 99998              False               False              False
# 99999              False               False              False
#
#        Street_York AVE  Street_York Valley Way  Street_Yorkwood DR  \
# 0                False                   False               False
# 1                False                   False               False
# 2                False                   False               False
# 3                False                   False               False
# 4                False                   False               False
# ...                ...                     ...                 ...
# 99995            False                   False               False
# 99996            False                   False               False
# 99997            False                   False               False
# 99998            False                   False               False
# 99999            False                   False               False
#
#        Street_Young ST  Street_Zawaly BAY
# 0                False              False
# 1                False              False
# 2                False              False
# 3                False              False
# 4                False              False
# ...                ...                ...
# 99995            False              False
# 99996            False              False
# 99997            False              False
# 99998            False              False
# 99999            False              False
#
# [100000 rows x 2619 columns]

# %%
df = df[['Longitude','Latitude']]
df = df.astype(np.float16)
encoded_columns_df["Latitude"] = df["Latitude"]
encoded_columns_df["Longitude"] = df["Longitude"]

# %%
df = encoded_columns_df
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0            False          False             False              False
# 1            False          False              True              False
# 2            False          False             False              False
# 3            False          False              True              False
# 4            False           True              True              False
# ...            ...            ...               ...                ...
# 99995        False          False              True              False
# 99996        False          False              True              False
# 99997        False          False             False              False
# 99998         True          False              True              False
# 99999        False           True              True              False
#
#        Violation Code_11  ...  Street_Yardley ST  Street_Yarwood AVE  \
# 0                  False  ...              False               False
# 1                  False  ...              False               False
# 2                  False  ...              False               False
# 3                  False  ...              False               False
# 4                  False  ...              False               False
# ...                  ...  ...                ...                 ...
# 99995              False  ...              False               False
# 99996              False  ...              False               False
# 99997              False  ...              False               False
# 99998              False  ...              False               False
# 99999              False  ...              False               False
#
#        Street_Yeomans ST  Street_York AVE  Street_York Valley Way  \
# 0                  False            False                   False
# 1                  False            False                   False
# 2                  False            False                   False
# 3                  False            False                   False
# 4                  False            False                   False
# ...                  ...              ...                     ...
# 99995              False            False                   False
# 99996              False            False                   False
# 99997              False            False                   False
# 99998              False            False                   False
# 99999              False            False                   False
#
#        Street_Yorkwood DR  Street_Young ST  Street_Zawaly BAY  Latitude  \
# 0                   False            False              False  -97.1875
# 1                   False            False              False  -97.1250
# 2                   False            False              False  -97.1250
# 3                   False            False              False  -97.1250
# 4                   False            False              False  -97.1250
# ...                   ...              ...                ...       ...
# 99995               False            False              False  -97.1250
# 99996               False            False              False  -97.1250
# 99997               False            False              False  -97.1875
# 99998               False            False              False  -97.1250
# 99999               False            False              False  -97.1250
#
#        Longitude
# 0       49.87500
# 1       49.87500
# 2       49.90625
# 3       49.87500
# 4       49.87500
# ...          ...
# 99995   49.90625
# 99996   49.90625
# 99997   49.90625
# 99998   49.87500
# 99999   49.90625
#
# [100000 rows x 2621 columns]

# %%
numericalCols = ["Longitude","Latitude"]
numericalData = df[numericalCols]

# standardize the numerical data to have a mean of 0 and a variance of 1
scaler = StandardScaler()
numericalDataScaled = scaler.fit_transform(numericalData)
df[numericalCols] = numericalDataScaled
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_10  \
# 0            False          False             False              False
# 1            False          False              True              False
# 2            False          False             False              False
# 3            False          False              True              False
# 4            False           True              True              False
# ...            ...            ...               ...                ...
# 99995        False          False              True              False
# 99996        False          False              True              False
# 99997        False          False             False              False
# 99998         True          False              True              False
# 99999        False           True              True              False
#
#        Violation Code_11  ...  Street_Yardley ST  Street_Yarwood AVE  \
# 0                  False  ...              False               False
# 1                  False  ...              False               False
# 2                  False  ...              False               False
# 3                  False  ...              False               False
# 4                  False  ...              False               False
# ...                  ...  ...                ...                 ...
# 99995              False  ...              False               False
# 99996              False  ...              False               False
# 99997              False  ...              False               False
# 99998              False  ...              False               False
# 99999              False  ...              False               False
#
#        Street_Yeomans ST  Street_York AVE  Street_York Valley Way  \
# 0                  False            False                   False
# 1                  False            False                   False
# 2                  False            False                   False
# 3                  False            False                   False
# 4                  False            False                   False
# ...                  ...              ...                     ...
# 99995              False            False                   False
# 99996              False            False                   False
# 99997              False            False                   False
# 99998              False            False                   False
# 99999              False            False                   False
#
#        Street_Yorkwood DR  Street_Young ST  Street_Zawaly BAY  Latitude  \
# 0                   False            False              False -1.258789
# 1                   False            False              False  0.373535
# 2                   False            False              False  0.373535
# 3                   False            False              False  0.373535
# 4                   False            False              False  0.373535
# ...                   ...              ...                ...       ...
# 99995               False            False              False  0.373535
# 99996               False            False              False  0.373535
# 99997               False            False              False -1.258789
# 99998               False            False              False  0.373535
# 99999               False            False              False  0.373535
#
#        Longitude
# 0      -0.559570
# 1      -0.559570
# 2       0.588379
# 3      -0.559570
# 4      -0.559570
# ...          ...
# 99995   0.588379
# 99996   0.588379
# 99997   0.588379
# 99998  -0.559570
# 99999   0.588379
#
# [100000 rows x 2621 columns]

# %%
dbscan = DBSCAN()

# Fit the model to the data
dbscan.fit_predict(df)

# add the cluster labels to the original dataframe
df['Clusters'] = dbscan.labels_

# %%
plt.scatter(df['Longitude'], df['Latitude'], c=df["Clusters"])
plt.title('Clustered Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0            True       False         False       False         False
# 1           False       False         False       False          True
# 2           False        True         False       False         False
# 3           False       False         False       False         False
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995       False       False         False       False         False
# 99996       False       False         False       False          True
# 99997       False       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False          True
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_2  \
# 0            False          False              True             False
# 1            False          False              True             False
# 2            False          False             False             False
# 3             True          False              True             False
# 4            False           True              True             False
# ...            ...            ...               ...               ...
# 99995        False           True             False             False
# 99996        False          False              True             False
# 99997        False           True             False             False
# 99998         True          False              True             False
# 99999        False          False              True             False
#
#        Violation Code_3  ...  Street_Zoe LANE  \
# 0                 False  ...            False
# 1                 False  ...            False
# 2                 False  ...            False
# 3                 False  ...            False
# 4                 False  ...            False
# ...                 ...  ...              ...
# 99995             False  ...            False
# 99996             False  ...            False
# 99997              True  ...            False
# 99998             False  ...            False
# 99999             False  ...            False
#
#        Time Range_Daytime (9:00am-3:30pm)  \
# 0                                    True
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                    True
# ...                                   ...
# 99995                                True
# 99996                               False
# 99997                               False
# 99998                               False
# 99999                                True
#
#        Time Range_Early Morning (5:30am-7:30am)  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 99995                                     False
# 99996                                     False
# 99997                                     False
# 99998                                     False
# 99999                                     False
#
#        Time Range_Evening (5:00pm-11:00pm)  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# ...                                    ...
# 99995                                False
# 99996                                False
# 99997                                False
# 99998                                False
# 99999                                False
#
#        Time Range_Overnight (11:00pm-5:30am)  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 99995                                  False
# 99996                                  False
# 99997                                  False
# 99998                                  False
# 99999                                  False
#
#        Time Range_Rush Hour Evening (3:30pm-5:00pm)  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 99995                                         False
# 99996                                         False
# 99997                                         False
# 99998                                          True
# 99999                                         False
#
#        Time Range_Rush Hour Morning (7:30am-9:00am)  Latitude  Longitude  \
# 0                                             False  0.374268  -0.575684
# 1                                             False  0.374268   0.603027
# 2                                             False  0.374268  -0.575684
# 3                                             False  0.374268   0.603027
# 4                                             False  0.374268  -0.575684
# ...                                             ...       ...        ...
# 99995                                         False  0.374268  -0.575684
# 99996                                          True  0.374268  -0.575684
# 99997                                          True -1.267578   0.603027
# 99998                                         False  0.374268   0.603027
# 99999                                         False  0.374268  -0.575684
#
#        Clusters
# 0            -1
# 1            -1
# 2            -1
# 3            -1
# 4            -1
# ...         ...
# 99995        -1
# 99996        -1
# 99997        -1
# 99998        -1
# 99999        -1
#
# [100000 rows x 2562 columns]

# %%
decoded_data = encoder.inverse_transform(encoded_data)
decoded_data
# Out:
# array([['Friday', 1, 'Donald ST', 'Daytime (9:00am-3:30pm)'],
#        ['Thursday', 1, 'Bannatyne AVE', 'Daytime (9:00am-3:30pm)'],
#        ['Monday', 13, 'Kennedy ST', 'Evening (5:00pm-11:00pm)'],
#        ...,
#        ['Wednesday', 3, 'William AVE',
#         'Rush Hour Morning (7:30am-9:00am)'],
#        ['Tuesday', 1, 'Pioneer AVE', 'Rush Hour Evening (3:30pm-5:00pm)'],
#        ['Thursday', 1, 'Kennedy ST', 'Daytime (9:00am-3:30pm)']],
#       dtype=object)

# %%
decodedDf= pd.DataFrame(decoded_data,columns=["Day","Violation Code","Street","Time Range"])
decodedDf["Cluster"]=df["Clusters"]
decodedDf
# Out:
#              Day Violation Code         Street  \
# 0         Friday              1      Donald ST
# 1       Thursday              1  Bannatyne AVE
# 2         Monday             13     Kennedy ST
# 3        Tuesday              1    St Mary AVE
# 4      Wednesday              1     Osborne ST
# ...          ...            ...            ...
# 99995  Wednesday             13     Vaughan ST
# 99996   Thursday              1    Edmonton ST
# 99997  Wednesday              3    William AVE
# 99998    Tuesday              1    Pioneer AVE
# 99999   Thursday              1     Kennedy ST
#
#                               Time Range  Cluster
# 0                Daytime (9:00am-3:30pm)       -1
# 1                Daytime (9:00am-3:30pm)       -1
# 2               Evening (5:00pm-11:00pm)       -1
# 3                Daytime (9:00am-3:30pm)       -1
# 4                Daytime (9:00am-3:30pm)       -1
# ...                                  ...      ...
# 99995            Daytime (9:00am-3:30pm)       -1
# 99996  Rush Hour Morning (7:30am-9:00am)       -1
# 99997  Rush Hour Morning (7:30am-9:00am)       -1
# 99998  Rush Hour Evening (3:30pm-5:00pm)       -1
# 99999            Daytime (9:00am-3:30pm)       -1
#
# [100000 rows x 5 columns]

# %%
# get the counts of the Cluster column
counts = decodedDf['Cluster'].value_counts()
counts_df = pd.DataFrame({'Cluster': counts.index, 'Count': counts.values})
noise = counts_df.iloc[0]
counts_df = counts_df.drop(counts_df.index[0])


counts_df = counts_df.sort_values('Cluster')
# plot the line chart
plt.plot(counts_df['Cluster'], counts_df['Count'])

# fill in the area underneath the line chart
plt.fill_between(counts_df['Cluster'], counts_df['Count'], alpha=0.3)

# set the x and y axis labels
plt.xlabel('Cluster')
plt.ylabel('Count')

plt.show()

# %%
noise
# Out:
# Cluster        -1
# Count      100000
# Name: 0, dtype: int64
