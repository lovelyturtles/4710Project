# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/timeRangedData.csv", low_memory=False)

# %%
mask = df['Violation Code'].str.startswith('MP')
df.loc[mask, 'Violation Code'] = df.loc[mask, 'Violation Code'].str.slice(start=2)

mask = df['Violation Code'].str.startswith('P')
df.loc[mask, 'Violation Code'] = df.loc[mask, 'Violation Code'].str.slice(start=1)
mask = df['Violation Code'].str.startswith('M')
df.loc[mask, 'Violation Code'] = df.loc[mask, 'Violation Code'].str.slice(start=1)

mask = df['Violation Code'].str.startswith('0')
df.loc[mask, 'Violation Code'] = df.loc[mask, 'Violation Code'].str.slice(start=1)

df['Time Range'] = df['Time Range'].replace({'Overnight 1 (11:00pm-12:00am)': 'Overnight (11:00pm-5:30am)', 'Overnight 2 (12:00am-5:30am)': 'Overnight (11:00pm-5:30am)'})

# %%
df.to_csv("../Data/mergedCodesandRangesCleanedData2.csv", index=False)
df
# Out:
#               Date         Street                  Location   Fine  \
# 0       2020-03-04    Hargrave ST       (49.8898, -97.1428)   60.0
# 1       2019-07-06  St Charles ST   (49.878495, -97.320433)   70.0
# 2       2020-03-10       Panet RD       (49.9022, -97.0701)  100.0
# 3       2019-06-28    Corydon AVE    (49.87113, -97.152496)   70.0
# 4       2020-03-25    Hargrave ST       (49.8855, -97.1402)   60.0
# ...            ...            ...                       ...    ...
# 493018  2019-06-08    Pembina HWY  (49.8357733, -97.150816)  100.0
# 493019  2019-05-28      Martha ST   (49.9008383, -97.13548)   70.0
# 493020  2019-06-05    Rothesay ST  (49.9374583, -97.080105)   70.0
# 493021  2019-05-16   McDermot AVE   (49.897315, -97.140835)   60.0
# 493022  2019-06-12      Dagmar ST   (49.899025, -97.145611)   60.0
#
#         Discounted Fine Violation Code         Violation Description  \
# 0                  45.0              1                 Meter Expired
# 1                  52.5              4             Oversized Vehicle
# 2                  75.0              9  Too close/in an intersection
# 3                  52.5              6                       No Stop
# 4                  45.0              1                 Meter Expired
# ...                 ...            ...                           ...
# 493018             75.0              9  Too close/in an intersection
# 493019             52.5             17   Too close to a traffic sign
# 493020             52.5             19       Crosswalk (MRKD/UNMRKD)
# 493021             45.0              1                 Meter Expired
# 493022             45.0              1                 Meter Expired
#
#                                Time Range
# 0                 Daytime (9:00am-3:30pm)
# 1              Overnight (11:00pm-5:30am)
# 2                 Daytime (9:00am-3:30pm)
# 3                Evening (5:00pm-11:00pm)
# 4       Rush Hour Morning (7:30am-9:00am)
# ...                                   ...
# 493018            Daytime (9:00am-3:30pm)
# 493019           Evening (5:00pm-11:00pm)
# 493020           Evening (5:00pm-11:00pm)
# 493021  Rush Hour Evening (3:30pm-5:00pm)
# 493022  Rush Hour Evening (3:30pm-5:00pm)
#
# [493023 rows x 8 columns]
