# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("../Data/cleanedSample.csv",low_memory=False)

# %%
df
# Out:
#        Longitude   Latitude       Street        Day  Violation Code
# 0      49.889043 -97.213038  Marjorie ST     Monday              37
# 1      49.889800 -97.145800  Edmonton ST     Friday               1
# 2      49.895800 -97.146300  Hargrave ST     Monday               2
# 3      49.889883 -97.147008  St Mary AVE   Thursday               1
# 4      49.889843 -97.136936      Fort ST  Wednesday               1
# ...          ...        ...          ...        ...             ...
# 99995  49.892040 -97.139610     Garry ST     Friday               1
# 99996  49.899393 -97.140131      King ST     Friday               1
# 99997  49.904600 -97.157500  William AVE     Friday               3
# 99998  49.886800 -97.145800   Kennedy ST    Tuesday               1
# 99999  49.892128 -97.152480  Balmoral ST  Wednesday               1
#
# [100000 rows x 5 columns]

# %%
# Select the columns to encode
columns_to_encode = ['Day', 'Violation Code', 'Street']

# Create the OneHotEncoder object
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore',dtype=np.bool_)

# Fit the encoder to the data
encoder.fit(df[columns_to_encode])

# Transform the data
encoded_data = encoder.transform(df[columns_to_encode])

# Create column names for the encoded data
encoded_columns = encoder.get_feature_names_out(columns_to_encode)

encoded_columns_df = pd.DataFrame(encoded_data, columns=encoded_columns)

encoded_columns_df = encoded_columns_df.astype(np.bool_)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
encoded_columns_df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_2  \
# 0            False          False             False             False
# 1            False          False              True             False
# 2            False          False             False              True
# 3            False          False              True             False
# 4            False           True              True             False
# ...            ...            ...               ...               ...
# 99995        False          False              True             False
# 99996        False          False              True             False
# 99997        False          False             False             False
# 99998         True          False              True             False
# 99999        False           True              True             False
#
#        Violation Code_3  ...  Street_Yale AVE W  Street_Yanofsky WAY  \
# 0                 False  ...              False                False
# 1                 False  ...              False                False
# 2                 False  ...              False                False
# 3                 False  ...              False                False
# 4                 False  ...              False                False
# ...                 ...  ...                ...                  ...
# 99995             False  ...              False                False
# 99996             False  ...              False                False
# 99997              True  ...              False                False
# 99998             False  ...              False                False
# 99999             False  ...              False                False
#
#        Street_Yardley ST  Street_Yarwood AVE  Street_Yeomans ST  \
# 0                  False               False              False
# 1                  False               False              False
# 2                  False               False              False
# 3                  False               False              False
# 4                  False               False              False
# ...                  ...                 ...                ...
# 99995              False               False              False
# 99996              False               False              False
# 99997              False               False              False
# 99998              False               False              False
# 99999              False               False              False
#
#        Street_York AVE  Street_York Valley Way  Street_Yorkwood DR  \
# 0                False                   False               False
# 1                False                   False               False
# 2                False                   False               False
# 3                False                   False               False
# 4                False                   False               False
# ...                ...                     ...                 ...
# 99995            False                   False               False
# 99996            False                   False               False
# 99997            False                   False               False
# 99998            False                   False               False
# 99999            False                   False               False
#
#        Street_Young ST  Street_Zawaly BAY
# 0                False              False
# 1                False              False
# 2                False              False
# 3                False              False
# 4                False              False
# ...                ...                ...
# 99995            False              False
# 99996            False              False
# 99997            False              False
# 99998            False              False
# 99999            False              False
#
# [100000 rows x 2615 columns]

# %%
df = df[['Longitude','Latitude']]
df = df.astype(np.float16)
encoded_columns_df["Latitude"] = df["Latitude"]
encoded_columns_df["Longitude"] = df["Longitude"]

# %%
df = encoded_columns_df
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_2  \
# 0            False          False             False             False
# 1            False          False              True             False
# 2            False          False             False              True
# 3            False          False              True             False
# 4            False           True              True             False
# ...            ...            ...               ...               ...
# 99995        False          False              True             False
# 99996        False          False              True             False
# 99997        False          False             False             False
# 99998         True          False              True             False
# 99999        False           True              True             False
#
#        Violation Code_3  ...  Street_Yardley ST  Street_Yarwood AVE  \
# 0                 False  ...              False               False
# 1                 False  ...              False               False
# 2                 False  ...              False               False
# 3                 False  ...              False               False
# 4                 False  ...              False               False
# ...                 ...  ...                ...                 ...
# 99995             False  ...              False               False
# 99996             False  ...              False               False
# 99997              True  ...              False               False
# 99998             False  ...              False               False
# 99999             False  ...              False               False
#
#        Street_Yeomans ST  Street_York AVE  Street_York Valley Way  \
# 0                  False            False                   False
# 1                  False            False                   False
# 2                  False            False                   False
# 3                  False            False                   False
# 4                  False            False                   False
# ...                  ...              ...                     ...
# 99995              False            False                   False
# 99996              False            False                   False
# 99997              False            False                   False
# 99998              False            False                   False
# 99999              False            False                   False
#
#        Street_Yorkwood DR  Street_Young ST  Street_Zawaly BAY  Latitude  \
# 0                   False            False              False  -97.1875
# 1                   False            False              False  -97.1250
# 2                   False            False              False  -97.1250
# 3                   False            False              False  -97.1250
# 4                   False            False              False  -97.1250
# ...                   ...              ...                ...       ...
# 99995               False            False              False  -97.1250
# 99996               False            False              False  -97.1250
# 99997               False            False              False  -97.1875
# 99998               False            False              False  -97.1250
# 99999               False            False              False  -97.1250
#
#        Longitude
# 0       49.87500
# 1       49.87500
# 2       49.90625
# 3       49.87500
# 4       49.87500
# ...          ...
# 99995   49.90625
# 99996   49.90625
# 99997   49.90625
# 99998   49.87500
# 99999   49.90625
#
# [100000 rows x 2617 columns]

# %%
numericalCols = ["Longitude","Latitude"]
numericalData = df[numericalCols]

# standardize the numerical data to have a mean of 0 and a variance of 1
scaler = StandardScaler()
numericalDataScaled = scaler.fit_transform(numericalData)
df[numericalCols] = numericalDataScaled
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_2  \
# 0            False          False             False             False
# 1            False          False              True             False
# 2            False          False             False              True
# 3            False          False              True             False
# 4            False           True              True             False
# ...            ...            ...               ...               ...
# 99995        False          False              True             False
# 99996        False          False              True             False
# 99997        False          False             False             False
# 99998         True          False              True             False
# 99999        False           True              True             False
#
#        Violation Code_3  ...  Street_Yardley ST  Street_Yarwood AVE  \
# 0                 False  ...              False               False
# 1                 False  ...              False               False
# 2                 False  ...              False               False
# 3                 False  ...              False               False
# 4                 False  ...              False               False
# ...                 ...  ...                ...                 ...
# 99995             False  ...              False               False
# 99996             False  ...              False               False
# 99997              True  ...              False               False
# 99998             False  ...              False               False
# 99999             False  ...              False               False
#
#        Street_Yeomans ST  Street_York AVE  Street_York Valley Way  \
# 0                  False            False                   False
# 1                  False            False                   False
# 2                  False            False                   False
# 3                  False            False                   False
# 4                  False            False                   False
# ...                  ...              ...                     ...
# 99995              False            False                   False
# 99996              False            False                   False
# 99997              False            False                   False
# 99998              False            False                   False
# 99999              False            False                   False
#
#        Street_Yorkwood DR  Street_Young ST  Street_Zawaly BAY  Latitude  \
# 0                   False            False              False -1.258789
# 1                   False            False              False  0.373535
# 2                   False            False              False  0.373535
# 3                   False            False              False  0.373535
# 4                   False            False              False  0.373535
# ...                   ...              ...                ...       ...
# 99995               False            False              False  0.373535
# 99996               False            False              False  0.373535
# 99997               False            False              False -1.258789
# 99998               False            False              False  0.373535
# 99999               False            False              False  0.373535
#
#        Longitude
# 0      -0.559570
# 1      -0.559570
# 2       0.588379
# 3      -0.559570
# 4      -0.559570
# ...          ...
# 99995   0.588379
# 99996   0.588379
# 99997   0.588379
# 99998  -0.559570
# 99999   0.588379
#
# [100000 rows x 2617 columns]

# %%
dbscan = DBSCAN()

# Fit the model to the data
dbscan.fit_predict(df)

# add the cluster labels to the original dataframe
df['Clusters'] = dbscan.labels_

# %%
plt.scatter(df['Longitude'], df['Latitude'], c=df["Clusters"])
plt.title('Clustered Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df
# Out:
#        Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# 0           False        True         False       False         False
# 1            True       False         False       False         False
# 2           False        True         False       False         False
# 3           False       False         False       False          True
# 4           False       False         False       False         False
# ...           ...         ...           ...         ...           ...
# 99995        True       False         False       False         False
# 99996        True       False         False       False         False
# 99997        True       False         False       False         False
# 99998       False       False         False       False         False
# 99999       False       False         False       False         False
#
#        Day_Tuesday  Day_Wednesday  Violation Code_1  Violation Code_2  \
# 0            False          False             False             False
# 1            False          False              True             False
# 2            False          False             False              True
# 3            False          False              True             False
# 4            False           True              True             False
# ...            ...            ...               ...               ...
# 99995        False          False              True             False
# 99996        False          False              True             False
# 99997        False          False             False             False
# 99998         True          False              True             False
# 99999        False           True              True             False
#
#        Violation Code_3  ...  Street_Yarwood AVE  Street_Yeomans ST  \
# 0                 False  ...               False              False
# 1                 False  ...               False              False
# 2                 False  ...               False              False
# 3                 False  ...               False              False
# 4                 False  ...               False              False
# ...                 ...  ...                 ...                ...
# 99995             False  ...               False              False
# 99996             False  ...               False              False
# 99997              True  ...               False              False
# 99998             False  ...               False              False
# 99999             False  ...               False              False
#
#        Street_York AVE  Street_York Valley Way  Street_Yorkwood DR  \
# 0                False                   False               False
# 1                False                   False               False
# 2                False                   False               False
# 3                False                   False               False
# 4                False                   False               False
# ...                ...                     ...                 ...
# 99995            False                   False               False
# 99996            False                   False               False
# 99997            False                   False               False
# 99998            False                   False               False
# 99999            False                   False               False
#
#        Street_Young ST  Street_Zawaly BAY  Latitude  Longitude  Clusters
# 0                False              False -1.258789  -0.559570         0
# 1                False              False  0.373535  -0.559570         1
# 2                False              False  0.373535   0.588379         2
# 3                False              False  0.373535  -0.559570         3
# 4                False              False  0.373535  -0.559570         4
# ...                ...                ...       ...        ...       ...
# 99995            False              False  0.373535   0.588379      1096
# 99996            False              False  0.373535   0.588379       687
# 99997            False              False -1.258789   0.588379      1312
# 99998            False              False  0.373535  -0.559570        10
# 99999            False              False  0.373535   0.588379       534
#
# [100000 rows x 2618 columns]

# %%
decoded_data = encoder.inverse_transform(encoded_data)
decoded_data
# Out:
# array([['Monday', 37, 'Marjorie ST'],
#        ['Friday', 1, 'Edmonton ST'],
#        ['Monday', 2, 'Hargrave ST'],
#        ...,
#        ['Friday', 3, 'William AVE'],
#        ['Tuesday', 1, 'Kennedy ST'],
#        ['Wednesday', 1, 'Balmoral ST']], dtype=object)

# %%
decodedDf= pd.DataFrame(decoded_data,columns=["Day","Violation Code","Street"])
decodedDf["Cluster"]=df["Clusters"]
decodedDf
# Out:
#              Day Violation Code       Street  Cluster
# 0         Monday             37  Marjorie ST        0
# 1         Friday              1  Edmonton ST        1
# 2         Monday              2  Hargrave ST        2
# 3       Thursday              1  St Mary AVE        3
# 4      Wednesday              1      Fort ST        4
# ...          ...            ...          ...      ...
# 99995     Friday              1     Garry ST     1096
# 99996     Friday              1      King ST      687
# 99997     Friday              3  William AVE     1312
# 99998    Tuesday              1   Kennedy ST       10
# 99999  Wednesday              1  Balmoral ST      534
#
# [100000 rows x 4 columns]

# %%
# get the counts of the Cluster column
counts = decodedDf['Cluster'].value_counts()
counts_df = pd.DataFrame({'Cluster': counts.index, 'Count': counts.values})
noise = counts_df.iloc[0]
counts_df = counts_df.drop(counts_df.index[0])


counts_df = counts_df.sort_values('Cluster')
# plot the line chart
plt.plot(counts_df['Cluster'], counts_df['Count'])

# fill in the area underneath the line chart
plt.fill_between(counts_df['Cluster'], counts_df['Count'], alpha=0.3)

# set the x and y axis labels
plt.xlabel('Cluster')
plt.ylabel('Count')

plt.show()

# %%
noiseDF = pd.DataFrame(noise,columns=["Cluster","Count"])
noiseDF.loc[0] = [noise[0],noise[1]]
noiseDF.to_csv("../Results/noiseDataWithMidnight.csv",index=False)
noiseDF
# Out:
#    Cluster  Count
# 0       -1  30874

# %%
dfnoLoc = df.drop(["Longitude","Latitude"],axis=1)
dbscan2 = DBSCAN()
dbscan2.fit_predict(dfnoLoc)

# add the cluster labels to the original dataframe
dfnoLoc['Clusters'] = dbscan2.labels_

# %%
graphData = pd.concat([pd.DataFrame(numericalDataScaled,columns=numericalCols), dfnoLoc], axis=1)

# %%
plt.scatter(graphData['Longitude'], graphData['Latitude'], c=graphData["Clusters"])
plt.title('Clustered Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
decoded_data2 = encoder.inverse_transform(dfnoLoc.drop("Clusters",axis=1))
decodedDf2= pd.DataFrame(decoded_data2,columns=["Day","Violation Code","Street"])
decodedDf2["Cluster"]=dfnoLoc["Clusters"]

# %%
# get the counts of the Cluster column
counts2 = decodedDf2['Cluster'].value_counts()
counts_df2 = pd.DataFrame({'Cluster': counts2.index, 'Count': counts2.values})
noise2 = counts_df2.iloc[0]
counts_df2 = counts_df2.drop(counts_df2.index[0])


counts_df2 = counts_df2.sort_values('Cluster')
# plot the line chart
plt.plot(counts_df2['Cluster'], counts_df2['Count'])

# fill in the area underneath the line chart
plt.fill_between(counts_df2['Cluster'], counts_df2['Count'], alpha=0.3)

# set the x and y axis labels
plt.xlabel('Cluster')
plt.ylabel('Count')

plt.show()

# %%
noiseDF2 = pd.DataFrame(noise2,columns=["Cluster","Count"])
noiseDF2.loc[0] = [noise2[0],noise2[1]]
noiseDF2.to_csv("../Results/noiseDataWithMidnightnoLoc.csv",index=False)
noiseDF2
# Out:
#    Cluster  Count
# 0       -1  28985
